# %%
import pandas as pd

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-m0b3212h
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-m0b3212h
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (10.6.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (0.9.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (4.67.1)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (3.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->openai-whisper==20240930) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->openai-whisper==20240930) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken->openai-whisper==20240930) (2.32.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->openai-whisper==20240930) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->openai-whisper==20240930) (3.0.2)

# %%
# !pip install ffmpeg
# Out:
# Requirement already satisfied: ffmpeg in /usr/local/lib/python3.11/dist-packages (1.4)

# %%
import whisper

def subs(index):
  # Load the Whisper model
  model = whisper.load_model("base")  # or "small", "medium", "large"

  # Transcribe the video file (replace 'your_video.mp4' with your actual file)
  result = model.transcribe(f"Atul{index}.mp4", verbose=True)

  # Save subtitles to an SRT file
  with open(f"subtitles{index}.srt", "w", encoding="utf-8") as srt_file:
      for i, segment in enumerate(result["segments"]):
          start = segment["start"]
          end = segment["end"]
          text = segment["text"].strip()

          # Format time
          def format_time(seconds):
              h = int(seconds // 3600)
              m = int((seconds % 3600) // 60)
              s = int(seconds % 60)
              ms = int((seconds - int(seconds)) * 1000)
              return f"{h:02}:{m:02}:{s:02},{ms:03}"

          srt_file.write(f"{i+1}\n")
          srt_file.write(f"{format_time(start)} --> {format_time(end)}\n")
          srt_file.write(f"{text}\n\n")

# %%
import re
from datetime import datetime

def parse_timestamp(ts):
    ts = ts.replace('.', ',')
    return datetime.strptime(ts, "%H:%M:%S,%f")

def extract_joy_cause_pairs(text_generated):
    pattern = r"Cause Timestamp: (.*?) --> (.*?)\nCause Text: (.*?)\nEmotion Timestamp: (.*?) --> (.*?)\nEmotion Text: (.*?)(?:\n|$)"

    matches = re.findall(pattern, text_generated)

    pairs = []

    for i, match in enumerate(matches, 1):
        cause_start, cause_end, cause_text, emotion_start, emotion_end, emotion_text = match

        min_start = min(parse_timestamp(cause_start), parse_timestamp(emotion_start))
        max_end = max(parse_timestamp(cause_end), parse_timestamp(emotion_end))

        pairs.append({
            "timestamp_range": f"{min_start.strftime('%H:%M:%S,%f')[:-3]} --> {max_end.strftime('%H:%M:%S,%f')[:-3]}",
            "cause_text": cause_text.strip(),
            "emotion_text": emotion_text.strip()
        })

    return pairs

# %%
import requests
import time

def get_all_subtitles(srt_file):
    with open(srt_file, 'r', encoding='utf-8') as f:
        return f.read().split('\n\n')  # Split each subtitle block

def join_srt_subs(sub_blocks):
    return '\n\n'.join(sub_blocks)

def create_prompt(srt_chunk):
    return f"""
You are an expert at analyzing subtitles and emotions in conversations.

Given subtitles in `.srt` format, extract all pairs of dialogue segments where:
- One subtitle expresses **joy** or **happiness** or **surprise**
- Another (previous or nearby) subtitle contains the **cause** or **reason** for that joy
- Time difference between the pairs should be 5 seconds max

For each pair, return:
1. Start and end timestamps of both subtitles
2. The text of both subtitles
3. Clearly mention which line is the "Emotion" and which one is the "Cause"

Only output pairs (Cause first then Emotion) where you can confidently identify joy and its cause. Ignore all other subtitles.

Follow the following Output Format:
Pair:
Cause Timestamp:
Cause Text:
Emotion Timestamp:
Emotion Text:

Now, analyze the following `.srt` content:

{srt_chunk}
"""

def send_to_gemini(prompt, API_KEY):
    endpoint = "https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent"
    headers = {"Content-Type": "application/json"}
    body = {
        "contents": [
            {
                "parts": [
                    {
                        "text": prompt
                    }
                ]
            }
        ]
    }

    response = requests.post(f"{endpoint}?key={API_KEY}", headers=headers, json=body)
    if response.status_code == 200:
        output = response.json()
        return output["candidates"][0]["content"]["parts"][0]["text"]
    else:
        print(f"Error: {response.status_code}\n{response.text}")
        return None

def process_subtitles(index):
    API_KEY = "AIzaSyCFZkfFpCJ3kX8XpcfnlgyAOcZIlWIZb_8"
    srt_file = f"subtitles{index}.srt"
    all_subs = get_all_subtitles(srt_file)
    total = len(all_subs)
    step = 30
    window = 50

    results = []

    for i, start in enumerate(range(0, total, step)):
        end = min(start + window, total)
        chunk = join_srt_subs(all_subs[start:end])
        prompt = create_prompt(chunk)

        print(f"Processing subtitles {start} to {end} (chunk {i+1})...")
        response_text = send_to_gemini(prompt, API_KEY)
        if response_text:
            chunk_res = extract_joy_cause_pairs(response_text)
            # print(response_text)
            # print(chunk_res)
            results.extend(chunk_res)

        if (i + 1) % 12 == 0:
            print("Sleeping for 60 seconds to avoid rate limiting...")
            time.sleep(60)

    return results

# %%
for i in range(2,9):
  time.sleep(60)
  subs(i)
  results = process_subtitles(i)
  len(results)
  df = pd.DataFrame(results)
  df.to_csv(f'Atul{i}.csv',index = False)
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:02.000]  I'm gonna be honest.
# [00:02.800 --> 00:03.800]  I nearly threw up.
# [00:03.800 --> 00:05.800]  LAUGHTER
# [00:06.800 --> 00:07.800]  I'm gonna do it.
# [00:18.800 --> 00:19.800]  Pops, hop, pop!
# [00:20.400 --> 00:21.400]  Ho-ee!
# [00:22.200 --> 00:23.000]  Pop!
# [00:23.000 --> 00:24.000]  Yeah, very good.
# [00:24.000 --> 00:25.600]  It's fair, good, fair to us.
# [00:25.600 --> 00:27.600]  Payton, how about now?
# [00:27.600 --> 00:29.800]  I'm good, how you're?
# [00:29.800 --> 00:32.600]  I am thirsty.
# [00:32.600 --> 00:35.400]  I'm thirsty too, but not as thirsty as you always.
# [00:35.400 --> 00:37.400]  What is that supposed to mean?
# [00:37.400 --> 00:39.000]  I can't find out.
# [00:39.000 --> 00:41.000]  That's trying to hide his erection.
# [00:45.000 --> 00:48.000]  OK, should we...
# [00:48.000 --> 00:49.000]  ...do it as his...
# [00:49.000 --> 00:50.000]  Yeah, you...
# [00:50.000 --> 00:51.000]  Yes, sure.
# [00:51.000 --> 00:52.000]  Would you just want to go first?
# [00:52.000 --> 00:53.000]  No.
# [00:53.000 --> 00:54.000]  See you, sirs.
# [00:54.000 --> 00:55.000]  Pay for a rock.
# [00:55.000 --> 00:56.200]  See you, sirs.
# [00:56.200 --> 00:57.200]  Pay for a rock.
# [00:57.200 --> 00:58.200]  See you, sirs.
# [00:58.200 --> 00:59.200]  Pay for a rock.
# [00:59.400 --> 01:00.400]  Oh!
# [19:24.600 --> 19:25.600]  Tell me.
# [19:25.600 --> 19:26.600]  The New York Jets.
# [19:34.600 --> 19:38.600]  I'm a fucking idiot.
# [19:39.600 --> 19:40.600]  Man, I just...
# [19:40.600 --> 19:43.600]  Fuck, it's always hit twice, you know what I mean.
# [19:45.600 --> 19:47.600]  Fuck, that's bad.
# [19:47.600 --> 19:48.600]  I know.
# [19:48.600 --> 19:49.600]  It is what it is.
# [19:49.600 --> 19:51.600]  We should have a look at it.
# [19:51.600 --> 19:52.600]  This is so bad.
# [19:52.600 --> 19:53.600]  Hey, welcome.
# [19:56.600 --> 19:58.600]  Go Payton!
# [19:58.600 --> 20:00.600]  Go Payton!
# [20:00.600 --> 20:01.600]  Go Payton!
# [20:01.600 --> 20:03.600]  You're the show.
# [20:05.600 --> 20:07.600]  I got one more.
# [20:07.600 --> 20:08.600]  What is it, too?
# [20:08.600 --> 20:10.600]  I punch at the wall.
# [20:10.600 --> 20:12.600]  A.
# Processing subtitles 0 to 50 (chunk 1)...
# Processing subtitles 30 to 80 (chunk 2)...
# Processing subtitles 60 to 110 (chunk 3)...
# Processing subtitles 90 to 140 (chunk 4)...
# Processing subtitles 120 to 170 (chunk 5)...
# Processing subtitles 150 to 200 (chunk 6)...
# Processing subtitles 180 to 230 (chunk 7)...
# Processing subtitles 210 to 260 (chunk 8)...
# Processing subtitles 240 to 290 (chunk 9)...
# Processing subtitles 270 to 320 (chunk 10)...
# Processing subtitles 300 to 350 (chunk 11)...
# Processing subtitles 330 to 380 (chunk 12)...
# Sleeping for 60 seconds to avoid rate limiting...
# Processing subtitles 360 to 410 (chunk 13)...
# Processing subtitles 390 to 440 (chunk 14)...
# Processing subtitles 420 to 470 (chunk 15)...
# Processing subtitles 450 to 496 (chunk 16)...
# Processing subtitles 480 to 496 (chunk 17)...
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:02.000]  I think you're gonna use mouth and get a pump and down on this.
# [00:02.000 --> 00:03.000]  You're gonna actually fix it.
# [00:03.000 --> 00:04.000]  You gotta erase that.
# [00:04.000 --> 00:05.000]  You mean?
# [00:05.000 --> 00:07.000]  You're gonna erase that.
# [00:21.000 --> 00:22.000]  Oh!
# [00:22.000 --> 00:23.000]  Hey buddy.
# [00:25.000 --> 00:26.000]  How are you?
# [00:26.000 --> 00:27.000]  It's been a while.
# [00:27.000 --> 00:28.000]  I'm good.
# [00:28.000 --> 00:29.000]  Yeah?
# [00:29.000 --> 00:31.000]  Is that how usual way of saying hello, isn't it?
# [00:31.000 --> 00:32.000]  Hello.
# [00:32.000 --> 00:33.000]  It's good to see you, man.
# [00:33.000 --> 00:34.000]  Likewise.
# [00:34.000 --> 00:35.000]  What's been going on?
# [00:35.000 --> 00:37.000]  Um, I don't know.
# [00:37.000 --> 00:38.000]  Not much.
# [00:38.000 --> 00:39.000]  I'm running.
# [00:39.000 --> 00:40.000]  Sumo.
# [00:40.000 --> 00:41.000]  How's that going?
# [00:41.000 --> 00:42.000]  It's going well.
# [00:42.000 --> 00:43.000]  That's going fine.
# [00:43.000 --> 00:44.000]  Yeah.
# [00:44.000 --> 00:46.000]  I'm wearing polar shirts now.
# [00:46.000 --> 00:47.000]  It looks great.
# [00:47.000 --> 00:48.000]  It looks exciting.
# [00:48.000 --> 00:49.000]  Thank you.
# [00:49.000 --> 00:50.000]  Thank you.
# [00:50.000 --> 00:51.000]  Digging the vibe.
# [00:51.000 --> 00:52.000]  Digging the look.
# [00:52.000 --> 00:53.000]  Digging.
# [00:53.000 --> 00:54.000]  What are you up to?
# [00:54.000 --> 00:55.000]  Just bring it back.
# [00:55.000 --> 00:56.000]  Anyway, let's get on to the segment.
# [00:56.000 --> 00:57.000]  Yeah, good chat.
# [00:57.000 --> 00:58.000]  Move on to the segment.
# [00:58.000 --> 01:00.000]  Um, would you like to start?
# [01:00.000 --> 01:02.000]  I would love to begin.
# [01:02.000 --> 01:04.000]  I'd love to begin.
# [01:04.000 --> 01:06.000]  Please tell me a joke.
# [01:06.000 --> 01:07.000]  How are you?
# [01:07.000 --> 01:08.000]  How are you?
# [01:08.000 --> 01:10.000]  I'm not tall enough.
# [01:10.000 --> 01:12.000]  You're a bit too weak.
# [01:12.000 --> 01:13.000]  That's my...
# [01:13.000 --> 01:14.000]  Oh, change...
# [01:14.000 --> 01:15.000]  Yeah, okay.
# [01:15.000 --> 01:16.000]  Tristan, my public is...
# [01:16.000 --> 01:17.000]  I changed.
# [01:17.000 --> 01:18.000]  Whoa!
# [01:18.000 --> 01:20.000]  You changed.
# [01:20.000 --> 01:21.000]  You've got famous?
# [01:21.000 --> 01:22.000]  Yeah.
# [01:22.000 --> 01:24.000]  What, um, life's about change.
# [01:24.000 --> 01:25.000]  Life's about change, pal.
# [01:25.000 --> 01:26.000]  Mmm.
# [01:26.000 --> 01:27.000]  Life's about change.
# [01:28.000 --> 01:30.000]  What do my ex-girlfriend
# [01:30.000 --> 01:32.000]  and a public toilet
# [01:32.000 --> 01:34.000]  have in common?
# [01:34.000 --> 01:35.000]  What?
# [01:35.000 --> 01:38.000]  Um, they're both usually busy
# [01:38.000 --> 01:40.000]  and full of shit.
# [01:43.000 --> 01:44.000]  All right.
# [01:44.000 --> 01:51.000]  What's Michael Jackson's favorite painting?
# [01:53.000 --> 01:56.000]  I could probably guess this one if I tried.
# [01:57.000 --> 01:59.000]  Van Gogh.
# [01:59.000 --> 02:02.000]  It's a monochleeta.
# [02:02.000 --> 02:05.000]  Oh, no.
# [02:09.000 --> 02:11.000]  How many of these do you have?
# [02:11.000 --> 02:12.000]  Hundreds.
# [02:12.000 --> 02:13.000]  Pages.
# [02:13.000 --> 02:16.000]  How did the TikTokers pay for their rent?
# [02:16.000 --> 02:20.000]  Now, by explaining this video is sponsored by Surfsharp.
# [02:20.000 --> 02:22.000]  It keeps your personal data protected
# [02:22.000 --> 02:24.000]  from online criminals and big companies.
# [02:24.000 --> 02:27.000]  A VPN makes sure that your city, country, and download history
# [02:27.000 --> 02:29.000]  aren't attached to your identity.
# [02:29.000 --> 02:31.000]  And that's important in this day and age.
# [02:31.000 --> 02:34.000]  Surfsharp's CleanWeb feature blocks ads, stops malware,
# [02:34.000 --> 02:37.000]  and keeps track of fishing attempts against you,
# [02:37.000 --> 02:39.000]  which means it's looking out for your best interest.
# [02:39.000 --> 02:41.000]  But Alan, what if I'm on holiday?
# [02:41.000 --> 02:42.000]  Shut up.
# [02:42.000 --> 02:43.000]  Doesn't matter about that.
# [02:43.000 --> 02:46.000]  You can change your geographical location back to your home country
# [02:46.000 --> 02:49.000]  so you can keep up with the movies and TV shows that you enjoy.
# [02:49.000 --> 02:50.000]  That's amazing.
# [02:50.000 --> 02:51.000]  Yeah.
# [02:51.000 --> 02:53.000]  Surfsharp offers a 30-day cashback guarantee,
# [02:53.000 --> 02:55.000]  which means there's no risk in trying.
# [02:55.000 --> 02:57.000]  You could do so much in 30 days.
# [02:57.000 --> 02:59.000]  You could watch every episode of Love Island.
# [02:59.000 --> 03:01.000]  And I, that's what I do every day.
# [03:01.000 --> 03:03.000]  Surfsharp offers a 30-day cashback guarantee,
# [03:03.000 --> 03:05.000]  which means you can try it and test it.
# [03:05.000 --> 03:07.000]  And if you don't like it, you can get your money back off the 30 days.
# [03:07.000 --> 03:10.000]  Use promo code, you're mad for three months for free.
# [03:10.000 --> 03:12.000]  What's more than three for three months?
# [03:12.000 --> 03:14.000]  You're getting me? What the heck?
# [03:14.000 --> 03:16.000]  Hit that link down below.
# [03:16.000 --> 03:20.000]  They say 9 out of 10 people suffer from diarrhea.
# [03:20.000 --> 03:23.000]  I guess that makes me number 10 because I love it.
# [03:35.000 --> 03:39.000]  What do you call it when two transgender b****s have sex?
# [03:42.000 --> 03:43.000]  Uh...
# [03:43.000 --> 03:44.000]  What?
# [03:44.000 --> 03:46.000]  Micro-transact.
# [03:51.000 --> 03:54.000]  I don't even get any more understand of that one.
# [03:54.000 --> 03:57.000]  Oh, all right.
# [03:57.000 --> 04:00.000]  I thought that was quite good.
# [04:02.000 --> 04:04.000]  Pull you off the booze.
# [04:04.000 --> 04:06.000]  Well, I mean...
# [04:06.000 --> 04:08.000]  I'm an artist.
# [04:08.000 --> 04:11.000]  I went for a walk with a girl the other day.
# [04:11.000 --> 04:13.000]  Hey, man.
# [04:14.000 --> 04:15.000]  Sorry.
# [04:18.000 --> 04:19.000]  Well, he's right.
# [04:19.000 --> 04:22.000]  It's tighter as a walk until she saw me in the bushes.
# [04:22.000 --> 04:24.000]  Then it became around, run.
# [04:24.000 --> 04:26.000]  And it became around.
# [04:26.000 --> 04:28.000]  It became around.
# [04:29.000 --> 04:31.000]  If you tell him what?
# [04:31.000 --> 04:33.000]  Around.
# [04:33.000 --> 04:35.000]  Around.
# [04:39.000 --> 04:41.000]  All right.
# [04:42.000 --> 04:44.000]  Have you got what?
# [04:47.000 --> 04:50.000]  Why is China bad at football?
# [04:53.000 --> 04:55.000]  Why?
# [04:55.000 --> 04:59.000]  Because every time they get a corner, they open a restaurant.
# [05:01.000 --> 05:03.000]  You know, like...
# [05:03.000 --> 05:05.000]  Chinese restaurants.
# [05:06.000 --> 05:09.000]  Do the accent.
# [05:09.000 --> 05:11.000]  Do the accent.
# [05:11.000 --> 05:13.000]  Reach a corner.
# [05:13.000 --> 05:15.000]  No, you're...
# [05:15.000 --> 05:17.000]  You're the only one.
# [05:17.000 --> 05:19.000]  You're the only one.
# [05:19.000 --> 05:21.000]  You did the team.
# [05:21.000 --> 05:22.000]  No.
# [05:22.000 --> 05:24.000]  No, the one.
# [05:24.000 --> 05:25.000]  No.
# [05:25.000 --> 05:27.000]  Not the one.
# [05:29.000 --> 05:32.000]  I hope you guys know that you're creating a culture of racial division.
# [05:32.000 --> 05:34.000]  Yes.
# [05:36.000 --> 05:39.000]  I was at the dentist the other day.
# [05:39.000 --> 05:42.000]  And the dentist said, oh, this is going to sting.
# [05:42.000 --> 05:44.000]  And I said, okay, go ahead.
# [05:44.000 --> 05:46.000]  And he says, you're a fat loser.
# [05:51.000 --> 05:52.000]  Is that...
# [05:52.000 --> 05:54.000]  Have you just modified one of your bits?
# [05:54.000 --> 05:55.000]  No.
# [05:55.000 --> 05:57.000]  Oh, I just kind of like that bit.
# [05:57.000 --> 05:59.000]  That's how the bit I had.
# [05:59.000 --> 06:04.000]  Have you said that movie where Johnny Depp gets molested?
# [06:04.000 --> 06:05.000]  No.
# [06:05.000 --> 06:07.000]  It's called Who's Eating Gilbert's Date?
# [06:07.000 --> 06:10.000]  He wrote that.
# [06:10.000 --> 06:13.000]  I thought it was a part of the Caribbean.
# [06:13.000 --> 06:15.000]  Like the Caribbean...
# [06:15.000 --> 06:16.000]  Oh, that's a big sense.
# [06:16.000 --> 06:18.000]  No, that doesn't make sense.
# [06:18.000 --> 06:22.000]  I thought it was called the fear and molesting.
# [06:22.000 --> 06:25.000]  He molested you.
# [06:25.000 --> 06:28.000]  I wanted to just do an hour of that.
# [06:28.000 --> 06:30.000]  I think I'm a cop.
# [06:30.000 --> 06:32.000]  I thought it was called...
# [06:33.000 --> 06:35.000]  Amber heard something.
# [06:35.000 --> 06:42.000]  But what's the difference between a hormone and a vitamin?
# [06:42.000 --> 06:44.000]  Oh, what?
# [06:44.000 --> 06:47.000]  You can't hear a vitamin.
# [06:47.000 --> 06:49.000]  Oh, I got that fear.
# [06:49.000 --> 06:50.000]  Yeah, that hurts.
# [06:50.000 --> 06:51.000]  Yeah, yeah, yeah.
# [06:51.000 --> 06:52.000]  I feel it.
# [06:52.000 --> 06:53.000]  That's good.
# [06:53.000 --> 06:55.000]  Yeah, because you can hear a hormone.
# [06:55.000 --> 06:58.000]  Yeah, well, we're going to work on our chemistry.
# [06:58.000 --> 07:01.000]  What do you call a Chinese guy with a camera?
# [07:01.000 --> 07:03.000]  I'm not a Ching Chong, right?
# [07:03.000 --> 07:04.000]  What?
# [07:04.000 --> 07:05.000]  What are you calling?
# [07:05.000 --> 07:06.000]  Filming!
# [07:06.000 --> 07:07.000]  Oh!
# [07:07.000 --> 07:08.000]  It's not a snapper.
# [07:08.000 --> 07:10.000]  It's not a Godzilla.
# [07:12.000 --> 07:14.000]  Dude, that's racist.
# [07:14.000 --> 07:16.000]  They can't say L.
# [07:17.000 --> 07:19.000]  Filming.
# [07:19.000 --> 07:21.000]  When...
# [07:24.000 --> 07:26.000]  Continue.
# [07:27.000 --> 07:29.000]  Fuck it.
# [07:29.000 --> 07:32.000]  Um...
# [07:32.000 --> 07:33.000]  Hey.
# [07:33.000 --> 07:34.000]  Homo...
# [07:34.000 --> 07:35.000]  Oh, hey.
# [07:35.000 --> 07:37.000]  Give me a joke.
# [07:37.000 --> 07:39.000]  The dude should do ASMR.
# [07:39.000 --> 07:40.000]  Give me a joke.
# [07:40.000 --> 07:42.000]  Did you know...
# [07:42.000 --> 07:46.000]  Homo was so... was in... was...
# [07:49.000 --> 07:53.000]  The other day, I saw a stop sign, a road sign.
# [07:53.000 --> 07:54.000]  Let me do that again.
# [07:54.000 --> 07:58.000]  One time, I saw a sign that said, watch for children.
# [07:58.000 --> 08:00.000]  And I thought to myself,
# [08:00.000 --> 08:02.000]  Huh, that's a good deal.
# [08:02.000 --> 08:04.000]  So I traded in my Rolex,
# [08:04.000 --> 08:07.000]  and now I get free iPhones and Jordans at home.
# [08:09.000 --> 08:11.000]  Because the children make them...
# [08:11.000 --> 08:16.000]  to... to joke about the child labor state.
# [08:16.000 --> 08:18.000]  Say the child labor of the man.
# [08:18.000 --> 08:20.000]  That's the real thing, yeah.
# [08:20.000 --> 08:21.000]  Oh.
# [08:21.000 --> 08:23.000]  You're a pedagogy.
# [08:23.000 --> 08:25.000]  This one will never make the...
# [08:25.000 --> 08:27.000]  I'm disappointed.
# [08:27.000 --> 08:29.000]  I'm disappointed.
# [08:29.000 --> 08:32.000]  My girlfriend told me to stop singing,
# [08:32.000 --> 08:35.000]  I'm a believer, or she dumped me.
# [08:35.000 --> 08:37.000]  I thought she was joking.
# [08:37.000 --> 08:38.000]  Yeah.
# [08:38.000 --> 08:40.000]  But then I saw her face.
# [08:40.000 --> 08:43.000]  And I'm a believer.
# [08:49.000 --> 08:52.000]  I'm not good at finding the clitoris.
# [08:54.000 --> 08:56.000]  I'm just joking.
# [08:56.000 --> 08:59.000]  Probably because I don't belong in the hood.
# [09:02.000 --> 09:03.000]  That was bad.
# [09:03.000 --> 09:05.000]  It didn't belly button.
# [09:05.000 --> 09:07.000]  And what?
# [09:07.000 --> 09:11.000]  Ellen, would you believe the doctor told me I had to stop masturbating?
# [09:11.000 --> 09:12.000]  I said, why doctor?
# [09:12.000 --> 09:15.000]  And he said, because I'm trying to examine you.
# [09:16.000 --> 09:18.000]  Oh.
# [09:18.000 --> 09:22.000]  It's just like the first joke that pops up when you Google down jokes.
# [09:22.000 --> 09:24.000]  It's just a joke.
# [09:24.000 --> 09:26.000]  Zero or all?
# [09:26.000 --> 09:28.000]  When Hammer was in prison,
# [09:28.000 --> 09:32.000]  he used to put butt, used to pour butter on all the bars of soap.
# [09:32.000 --> 09:35.000]  So people would drop them more when in the shower.
# [09:35.000 --> 09:37.000]  There's a dirty little freak.
# [09:37.000 --> 09:39.000]  Isn't soap already separate?
# [09:39.000 --> 09:41.000]  Yeah, but you met at Atrice Lippurit.
# [09:41.000 --> 09:43.000]  You said it would constantly drop.
# [09:43.000 --> 09:44.000]  Oh, okay.
# [09:44.000 --> 09:45.000]  That's what you do.
# [09:45.000 --> 09:46.000]  You're a slippery guy.
# [09:46.000 --> 09:48.000]  You're a manipulative fucking.
# [09:48.000 --> 09:50.000]  You're a shit.
# [09:50.000 --> 09:52.000]  I'm ungrateful little freak.
# [09:52.000 --> 09:54.000]  Oh!
# [09:54.000 --> 09:56.000]  I'm agent.
# [09:56.000 --> 09:58.000]  Now I feel like I'm a...
# [09:58.000 --> 10:00.000]  I'm a doctor's masturbating.
# [10:00.000 --> 10:02.000]  I like...
# [10:02.000 --> 10:04.000]  Shut the fuck up, Ellen.
# [10:10.000 --> 10:12.000]  Why are chickens so funny?
# [10:12.000 --> 10:14.000]  Why?
# [10:15.000 --> 10:17.000]  Um...
# [10:18.000 --> 10:20.000]  Oh, I know that one.
# [10:20.000 --> 10:22.000]  It's the...
# [10:22.000 --> 10:24.000]  I think I was gonna do that.
# [10:24.000 --> 10:26.000]  Oh, because they make good jokes.
# [10:26.000 --> 10:29.000]  No, can you not trample on my fucking punch lines?
# [10:29.000 --> 10:31.000]  Oh, fucking dickhead.
# [10:31.000 --> 10:34.000]  Is why I didn't want to work with him today?
# [10:34.000 --> 10:36.000]  Fucking hell.
# [10:36.000 --> 10:38.000]  All right, I tell you, stupid fucking robot.
# [10:38.000 --> 10:40.000]  I'm trying to have fun.
# [10:40.000 --> 10:41.000]  You're not...
# [10:41.000 --> 10:43.000]  It's kind of your fault that it's not going well.
# [10:43.000 --> 10:45.000]  Fuck off.
# [10:45.000 --> 10:47.000]  Oh, fuck.
# [10:47.000 --> 10:49.000]  What?
# [10:49.000 --> 10:51.000]  I wanted to say something.
# [10:51.000 --> 10:53.000]  I wanted to stop looking at something.
# [10:53.000 --> 10:55.000]  You did it.
# [10:55.000 --> 10:59.000]  You did some good jokes or what?
# [10:59.000 --> 11:01.000]  Fuck me.
# [11:01.000 --> 11:03.000]  I was talking to fucking software.
# [11:03.000 --> 11:05.000]  Fuck you.
# [11:05.000 --> 11:07.000]  Stop.
# [11:07.000 --> 11:09.000]  Stop.
# [11:09.000 --> 11:11.000]  I was just joking.
# [11:11.000 --> 11:13.000]  I was just joking.
# [11:13.000 --> 11:15.000]  I was just joking.
# [11:15.000 --> 11:17.000]  It was a fun hit.
# [11:17.000 --> 11:19.000]  Yeah, it was a fun hit.
# [11:19.000 --> 11:21.000]  Yeah, it was a fun hit.
# [11:21.000 --> 11:23.000]  It's not.
# [11:23.000 --> 11:25.000]  Yeah, I still work non-stop.
# [11:25.000 --> 11:27.000]  Why are chickens so funny?
# [11:27.000 --> 11:29.000]  Why?
# [11:29.000 --> 11:31.000]  Why?
# [11:31.000 --> 11:33.000]  Because!
# [11:33.000 --> 11:35.000]  Oh, yeah, yeah.
# [11:35.000 --> 11:37.000]  Nice.
# [11:37.000 --> 11:39.000]  I'm so confused.
# [11:39.000 --> 11:41.000]  It's too...
# [11:41.000 --> 11:43.000]  What?
# [11:43.000 --> 11:45.000]  It's dead, I'm just moving back together.
# [11:45.000 --> 11:47.000]  I still don't know if I'm attracted to the hammer world.
# [11:47.000 --> 11:49.000]  What the hell?
# [11:49.000 --> 11:51.000]  What the hell?
# [11:51.000 --> 11:53.000]  You're like, I'm a man.
# [11:53.000 --> 11:55.000]  Love you, Syracuse.
# [11:55.000 --> 11:57.000]  What?
# [11:57.000 --> 11:59.000]  Are you a pothole?
# [11:59.000 --> 12:01.000]  That was great, I think.
# [12:01.000 --> 12:03.000]  I was like, fuck you.
# [12:03.000 --> 12:05.000]  I'm a bit scared.
# [12:05.000 --> 12:07.000]  I was mad at you.
# [12:07.000 --> 12:09.000]  I was like, fuck you.
# [12:09.000 --> 12:11.000]  Let's go!
# [12:11.000 --> 12:13.000]  I think it's your turn.
# [12:13.000 --> 12:15.000]  That's funny, Steve.
# [12:15.000 --> 12:19.000]  I just wanted to know, I wasn't going to talk to him once I started doing this.
# [12:19.000 --> 12:21.000]  Just make sure that.
# [12:21.000 --> 12:25.000]  The cat says otherwise, I mean.
# [12:25.000 --> 12:31.000]  Hammer's new special, it should be called Oranges the New Hack.
# [12:31.000 --> 12:33.000]  That's a good idea.
# [12:33.000 --> 12:35.000]  That's a good idea.
# [12:35.000 --> 12:37.000]  That's a good idea.
# [12:37.000 --> 12:41.000]  That was better than any of your roast jokes to get the killer.
# [12:41.000 --> 12:43.000]  You lost his wall pal.
# [12:43.000 --> 12:45.000]  Yeah, the user that says otherwise.
# [12:45.000 --> 12:47.000]  I guess it should be kissing makeup.
# [12:47.000 --> 12:49.000]  Yes.
# [12:49.000 --> 12:53.000]  Are you tracking down?
# [12:53.000 --> 12:55.000]  Oh.
# [12:55.000 --> 12:57.000]  Yeah.
# [12:57.000 --> 12:59.000]  What's that, Rayby?
# [12:59.000 --> 13:01.000]  What's that?
# [13:01.000 --> 13:03.000]  It's called Taking Charge.
# [13:03.000 --> 13:05.000]  What about this?
# [13:05.000 --> 13:07.000]  This is what disillite in the mood.
# [13:07.000 --> 13:09.000]  I suggested to my wife that she looks sexy with her hair back.
# [13:09.000 --> 13:11.000]  Oh.
# [13:11.000 --> 13:15.000]  Apparently, that's incisited to say to someone during chemo.
# [13:15.000 --> 13:17.000]  Oh, fuck.
# [13:17.000 --> 13:19.000]  She doesn't whip that hair back and forth.
# [13:19.000 --> 13:21.000]  Cancer does.
# [13:21.000 --> 13:25.000]  It's the same joke that he told.
# [13:25.000 --> 13:28.000]  To reminisce about prison,
# [13:28.000 --> 13:30.000]  Hammer sometimes does an escape room,
# [13:30.000 --> 13:35.000]  while being angly penetrated by the security guard.
# [13:35.000 --> 13:37.000]  Just to reminisce.
# [13:37.000 --> 13:39.000]  Did you find these on the internet or did you write these on the road?
# [13:39.000 --> 13:41.000]  Yeah, I could tell.
# [13:41.000 --> 13:43.000]  Because they're good.
# [13:43.000 --> 13:47.000]  How can you tell if your wife is dead?
# [13:47.000 --> 13:49.000]  I don't know how.
# [13:49.000 --> 13:53.000]  The sex is the same, but the dishes start to pile up.
# [13:53.000 --> 13:55.000]  Oh, God.
# [14:01.000 --> 14:05.000]  You know, learning the dishwasher or whatever.
# [14:05.000 --> 14:07.000]  That's pretty nice.
# [14:07.000 --> 14:09.000]  That's good gear.
# [14:09.000 --> 14:13.000]  I don't use dishes. I just get taken out.
# [14:13.000 --> 14:19.000]  Hammer is so fat, not even door ought to explore him.
# [14:19.000 --> 14:22.000]  That's a child, cousin.
# [14:22.000 --> 14:25.000]  When you were a regular heavy 32,
# [14:25.000 --> 14:28.000]  these are those jokes.
# [14:28.000 --> 14:30.000]  This is not good.
# [14:30.000 --> 14:32.000]  Me as well.
# [14:32.000 --> 14:34.000]  Here we go.
# [14:34.000 --> 14:36.000]  Self-chop.
# [14:36.000 --> 14:38.000]  That's so much.
# [14:38.000 --> 14:42.000]  And the shot is actually more intense.
# [14:45.000 --> 14:47.000]  Just a fella.
# [14:53.000 --> 14:55.000]  That's how it goes.
# [14:55.000 --> 14:57.000]  That's how it goes.
# [14:57.000 --> 15:00.000]  You're up.
# [15:00.000 --> 15:02.000]  Alex.
# [15:02.000 --> 15:06.000]  Come back to us.
# [15:06.000 --> 15:10.000]  He's drooling.
# [15:10.000 --> 15:14.000]  Would you like a tissue?
# [15:14.000 --> 15:16.000]  Yeah.
# [15:16.000 --> 15:20.000]  Good thing it's good and free.
# [15:20.000 --> 15:23.000]  How about you?
# [15:23.000 --> 15:26.000]  Where's the bottom?
# [15:26.000 --> 15:30.000]  You put your finger in his mouth and get him on this.
# [15:30.000 --> 15:32.000]  You got to raise it up.
# [15:32.000 --> 15:36.000]  Oh my God.
# [15:36.000 --> 15:39.000]  Holy shit.
# [15:39.000 --> 15:42.000]  Holy shit.
# [15:42.000 --> 15:45.000]  Holy shit.
# [15:45.000 --> 15:49.000]  Wow, Nikki eats a lot of pineapple.
# [15:49.000 --> 15:52.000]  Oh my God.
# [15:52.000 --> 15:55.000]  That's so much.
# [15:55.000 --> 15:58.000]  That's so good.
# [15:58.000 --> 16:02.000]  Guys, can we just get back to the jugs?
# [16:02.000 --> 16:05.000]  This is it.
# [16:05.000 --> 16:08.000]  Fuck, get that.
# [16:08.000 --> 16:10.000]  It's a lot of pineapple.
# [16:10.000 --> 16:13.000]  It's supposed to be about the jugs.
# [16:13.000 --> 16:16.000]  Another one.
# [16:16.000 --> 16:18.000]  I'm gonna get it.
# [16:18.000 --> 16:20.000]  You didn't even finish your last shot.
# [16:20.000 --> 16:22.000]  I know.
# [16:22.000 --> 16:25.000]  Don't hold them though.
# [16:25.000 --> 16:29.000]  Oh my God.
# [16:29.000 --> 16:32.000]  Is it my joke?
# [16:32.000 --> 16:37.000]  How many feminists does it take to change a light bulb?
# [16:37.000 --> 16:39.000]  I don't know.
# [16:39.000 --> 16:40.000]  Don't be stupid.
# [16:40.000 --> 16:42.000]  Feminists can't change anything.
# [16:42.000 --> 16:45.000]  Am I right?
# [16:45.000 --> 16:48.000]  We should ask our local feminists.
# [16:48.000 --> 16:52.000]  What do you think about that?
# [16:52.000 --> 16:59.000]  What's the difference between a rock star and a gynecologist?
# [16:59.000 --> 17:06.000]  A rock star fucks his singers while a gynecologist sucks his fingers.
# [17:06.000 --> 17:09.000]  I give you love, I love it.
# [17:09.000 --> 17:12.000]  I give you love that one.
